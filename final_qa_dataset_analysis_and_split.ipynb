# %%
import pandas as pd

# %%
df = pd.read_csv('/content/question_answers_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             business_id                          name  \
# 0           0  JGVxKGvQEaMZ6O_2l0UucA  Adelphia Restaurant & Events
# 1           1  JGVxKGvQEaMZ6O_2l0UucA  Adelphia Restaurant & Events
# 2           2  JGVxKGvQEaMZ6O_2l0UucA  Adelphia Restaurant & Events
# 3           3  JGVxKGvQEaMZ6O_2l0UucA  Adelphia Restaurant & Events
# 4           4  JGVxKGvQEaMZ6O_2l0UucA  Adelphia Restaurant & Events
#
#                                             question question_category  \
# 0   How is the food at Adelphia Restaurant & Events?      Food Quality
# 1  Is the food tasty at Adelphia Restaurant & Eve...      Food Quality
# 2  How are the portions at Adelphia Restaurant & ...      Food Quality
# 3  Is the food fresh at Adelphia Restaurant & Eve...      Food Quality
# 4   How is the menu at Adelphia Restaurant & Events?      Food Quality
#
#                                               answer  \
# 0  Based on the reviews, the food at Adelphia Res...
# 1  Yes, according to the reviews, the food at Ade...
# 2  The reviews mention that the portions at Adelp...
# 3  Yes, according to the reviews, the food at Ade...
# 4  The menu at Adelphia Restaurant & Events is de...
#
#                                              context
# 0  Review 1 (2012-02-16 19:23:50, Very Positive):...
# 1  Review 1 (2014-08-25 19:46:11, Positive):\nAde...
# 2  Review 1 (2012-02-16 19:23:50, Very Positive):...
# 3  Review 1 (2017-09-17 18:23:23, Very Positive):...
# 4  Review 1 (2012-02-16 19:23:50, Very Positive):...

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

def analyze_restaurant_questions(df):
    new_category_counts = df['question_category'].value_counts()

    questions_by_restaurant_category = pd.crosstab(
        df['business_id'],
        df['question_category']
    )

    restaurant_counts = df.groupby('business_id').size()

    fig1 = px.bar(
        x=new_category_counts.index,
        y=new_category_counts.values,
        title='Distribution of Questions by Category',
        labels={'x': 'Category', 'y': 'Number of Questions'},
        color=new_category_counts.values,
        color_continuous_scale='Viridis'
    )
    fig1.update_layout(
        xaxis_tickangle=-45,
        showlegend=False,
        height=600
    )

    fig2 = px.pie(
        values=new_category_counts.values,
        names=new_category_counts.index,
        title='Proportion of Questions by Category'
    )

    heatmap = px.imshow(
        questions_by_restaurant_category,
        title='Questions Distribution: Restaurants vs Categories',
        aspect='auto',
        color_continuous_scale='Viridis'
    )
    heatmap.update_layout(
        xaxis_tickangle=-45,
        height=800
    )

    fig4 = px.bar(
        x=restaurant_counts.index,
        y=restaurant_counts.values,
        title='Number of Questions per Restaurant',
        labels={'x': 'Restaurant', 'y': 'Number of Questions'},
        color=restaurant_counts.values,
        color_continuous_scale='Viridis'
    )
    fig4.update_layout(
        xaxis_tickangle=-45,
        showlegend=False,
        height=600
    )

    return new_category_counts, questions_by_restaurant_category, restaurant_counts, fig1, fig2, heatmap, fig4

# %%
category_counts, rest_cat_matrix, rest_counts, fig1, fig2, hmap, fig4 = analyze_restaurant_questions(df)

fig1.show()
fig2.show()
hmap.show()
fig4.show()
# Out:
# Category Counts:
# question_category
# Service                         3071
# Popular Dishes                  2434
# Special Features/Events         2026
# Food Quality                    1560
# Ambiance                        1265
# Special Dietary Requirements    1229
# Price                           1155
# Location/Accessibility          1021
# Reservation Process              812
# Wait Times                       772
# Name: count, dtype: int64
#
# Restaurant Category Matrix:
# question_category       Ambiance  Food Quality  Location/Accessibility  \
# business_id
# -T5SfUI_QqgBrkq4D8Jn7w        32            31                      21
# -pyobEWdpZ6jUp42f3I2xw        20            20                      20
# -qk__vjJxfJrCWn3UaMv_Q        25            47                      21
# 1hPvAr6D7yPpGbD_4RMqmQ        25            29                      21
# 47Xuiwsv_YsJIm7Px_mNWQ        32            29                      22
# 4WJqHhAq_CbtpzNiUuE9Eg        32            30                      22
# 4e9tguRcMc4S5hzBlfC62A        20            20                      20
# 5KS5b5-ip8znhJS_CYdzeQ        25            32                      22
# 5X0M4waoFm4kH612ezVvtA        25            44                      21
# 6imUPmHGgo9uknaoJXv79A        25            34                      21
# 7McQCpcpjyAA_TaQPlsirg        32            33                      21
# 9gPLN_mLR-kqwmcMe-QkOA        25            29                      22
# 9piIhWbzbr-47RL-Rh63Iw        32            40                      22
# DL5IVX_42Ra6DEq5d7NLrw        28            41                      22
# Dh65GRW4FmOEjDv_UuPP4A        26            32                      22
# JGVxKGvQEaMZ6O_2l0UucA        25            32                      22
# JNBuXPEjE3eavcIUvUc49A        20            20                      15
# Mfvk9uEEhdCqj8S2u7dWgQ        37            36                      22
# O1kxISHZDJj55d4G2Xoevg        26            29                      22
# OLSFUxfRCjLNPi49yOOrsQ        25            50                      21
# ObDQDZEAyFCw8Dy803_O6Q        25            29                      22
# RTwDv2oLE3gzAZlf63OPXA        20            20                      20
# RuPk-ScXo4ycpdnAkpfoNg        25            30                      22
# S2cKcdtOIDFyUfXYNPJUIw        25            38                      21
# UQMUtySn2q9cSObiw5UVsw        20            20                      20
# VwDrUaY7PPkvfD6M1dAVBQ        25            32                      22
# WNqqyUtEmrqCBEHNV9sj5Q        32            44                      21
# Wr2k0Vz8RbcumYulp-jIrA        25            37                      21
# X4mouE_cMiwbfyCPZ_K-FA        25            28                      22
# YH4q3-gWnglR1vstuEM8nA        25            30                      22
# Ylc02u7HhDj0mnxeGt0y5Q        25            41                      21
# bbL7sLg9gR3_08LZOriyTA        25            29                      22
# cBiHULO8B4gTEav8eQJhuQ        25            38                      22
# f8MSbvd5JotxsFsS6fbl-Q        32            44                      22
# g1phwUfq_-S8ZYTRqoG6iw        25            29                      21
# i1WPpsuD5gyLppyB71vv6A        32            39                      22
# i76ERS3jM111T3VMbi2yrQ        20            20                      20
# kQRB8RNwd7cEMcURTS-I7A        20            20                      20
# lML_PZePqlBBWpD1tqRdaA        25            35                      22
# lstgSw6ejDzZRZLf446x8Q        32            32                      21
# onp9X_9RRAEzA-yqdiSOcA        15            19                      18
# p8ao29A31ijNwDXuAxQxjA        32            32                      21
# pDOmFcUzaCzh2ETvx6z4BQ        25            38                      21
# rWjFmr0hhi2w8IwMu162-Q        25            38                      21
# ssr49VxAlvrBo7F7izQvXA        32            29                      21
# vP6BGF8IqbXlLQiDP5n6dA        26            42                      22
# vV57YWbrHqm1iylWmIdwVA        20            20                       6
# wb_z1h7XR5IQhVRZHlMuLQ        20            20                      21
# xtWIORPp-HG2LWtz5jQtiA        25            29                      22
#
# question_category       Popular Dishes  Price  Reservation Process  Service  \
# business_id
# -T5SfUI_QqgBrkq4D8Jn7w              58     26                   16       70
# -pyobEWdpZ6jUp42f3I2xw              20     20                   20       20
# -qk__vjJxfJrCWn3UaMv_Q              57     16                   16       71
# 1hPvAr6D7yPpGbD_4RMqmQ              57     24                   16       78
# 47Xuiwsv_YsJIm7Px_mNWQ              57     24                   16       79
# 4WJqHhAq_CbtpzNiUuE9Eg              60     26                   16       71
# 4e9tguRcMc4S5hzBlfC62A              20     20                   20       20
# 5KS5b5-ip8znhJS_CYdzeQ              58     26                   16       71
# 5X0M4waoFm4kH612ezVvtA              55     23                   16       72
# 6imUPmHGgo9uknaoJXv79A              57     25                   16       70
# 7McQCpcpjyAA_TaQPlsirg              60     16                   16       70
# 9gPLN_mLR-kqwmcMe-QkOA              57     24                   16       79
# 9piIhWbzbr-47RL-Rh63Iw              59     25                   16       71
# DL5IVX_42Ra6DEq5d7NLrw              54     22                   16       71
# Dh65GRW4FmOEjDv_UuPP4A              54     27                   16       76
# JGVxKGvQEaMZ6O_2l0UucA              57     25                   16       71
# JNBuXPEjE3eavcIUvUc49A              25     20                   20       20
# Mfvk9uEEhdCqj8S2u7dWgQ              55     20                   16       80
# O1kxISHZDJj55d4G2Xoevg              57     24                   16       71
# OLSFUxfRCjLNPi49yOOrsQ              69     38                   16       74
# ObDQDZEAyFCw8Dy803_O6Q              57     24                   16       79
# RTwDv2oLE3gzAZlf63OPXA              21     22                   22       21
# RuPk-ScXo4ycpdnAkpfoNg              59     26                   16       71
# S2cKcdtOIDFyUfXYNPJUIw              57     24                   16       70
# UQMUtySn2q9cSObiw5UVsw              12     20                   20       20
# VwDrUaY7PPkvfD6M1dAVBQ              60     25                   16       71
# WNqqyUtEmrqCBEHNV9sj5Q              57     26                   16       70
# Wr2k0Vz8RbcumYulp-jIrA              58     25                   16       71
# X4mouE_cMiwbfyCPZ_K-FA              56     23                   16       78
# YH4q3-gWnglR1vstuEM8nA              57     24                   16       71
# Ylc02u7HhDj0mnxeGt0y5Q              55     24                   16       71
# bbL7sLg9gR3_08LZOriyTA              57     24                   16       79
# cBiHULO8B4gTEav8eQJhuQ              57     23                   16       71
# f8MSbvd5JotxsFsS6fbl-Q              58     20                   16       73
# g1phwUfq_-S8ZYTRqoG6iw              57     24                   16       79
# i1WPpsuD5gyLppyB71vv6A              66     33                   16       89
# i76ERS3jM111T3VMbi2yrQ              20     20                   20       21
# kQRB8RNwd7cEMcURTS-I7A              20     20                   20       20
# lML_PZePqlBBWpD1tqRdaA              57     29                   16       72
# lstgSw6ejDzZRZLf446x8Q              60     27                   16       70
# onp9X_9RRAEzA-yqdiSOcA              19     19                   19       18
# p8ao29A31ijNwDXuAxQxjA              60     27                   16       71
# pDOmFcUzaCzh2ETvx6z4BQ              57     25                   16       70
# rWjFmr0hhi2w8IwMu162-Q              57     24                   16       70
# ssr49VxAlvrBo7F7izQvXA              57     24                   16       79
# vP6BGF8IqbXlLQiDP5n6dA              55     28                   17       72
# vV57YWbrHqm1iylWmIdwVA               5     10                    6       20
# wb_z1h7XR5IQhVRZHlMuLQ              20     20                   20       20
# xtWIORPp-HG2LWtz5jQtiA              57     24                   16       79
#
# question_category       Special Dietary Requirements  Special Features/Events  \
# business_id
# -T5SfUI_QqgBrkq4D8Jn7w                            29                       50
# -pyobEWdpZ6jUp42f3I2xw                            20                       20
# -qk__vjJxfJrCWn3UaMv_Q                            22                       52
# 1hPvAr6D7yPpGbD_4RMqmQ                            28                       41
# 47Xuiwsv_YsJIm7Px_mNWQ                            28                       53
# 4WJqHhAq_CbtpzNiUuE9Eg                            30                       54
# 4e9tguRcMc4S5hzBlfC62A                            20                       20
# 5KS5b5-ip8znhJS_CYdzeQ                            29                       40
# 5X0M4waoFm4kH612ezVvtA                            24                       43
# 6imUPmHGgo9uknaoJXv79A                            27                       46
# 7McQCpcpjyAA_TaQPlsirg                            25                       52
# 9gPLN_mLR-kqwmcMe-QkOA                            28                       42
# 9piIhWbzbr-47RL-Rh63Iw                            21                       58
# DL5IVX_42Ra6DEq5d7NLrw                            24                       47
# Dh65GRW4FmOEjDv_UuPP4A                            26                       48
# JGVxKGvQEaMZ6O_2l0UucA                            28                       44
# JNBuXPEjE3eavcIUvUc49A                            20                       20
# Mfvk9uEEhdCqj8S2u7dWgQ                            23                       56
# O1kxISHZDJj55d4G2Xoevg                            28                       53
# OLSFUxfRCjLNPi49yOOrsQ                            33                       44
# ObDQDZEAyFCw8Dy803_O6Q                            28                       42
# RTwDv2oLE3gzAZlf63OPXA                            24                       21
# RuPk-ScXo4ycpdnAkpfoNg                            29                       40
# S2cKcdtOIDFyUfXYNPJUIw                            24                       47
# UQMUtySn2q9cSObiw5UVsw                            20                       20
# VwDrUaY7PPkvfD6M1dAVBQ                            28                       45
# WNqqyUtEmrqCBEHNV9sj5Q                            25                       44
# Wr2k0Vz8RbcumYulp-jIrA                            23                       47
# X4mouE_cMiwbfyCPZ_K-FA                            28                       43
# YH4q3-gWnglR1vstuEM8nA                            28                       43
# Ylc02u7HhDj0mnxeGt0y5Q                            24                       45
# bbL7sLg9gR3_08LZOriyTA                            28                       46
# cBiHULO8B4gTEav8eQJhuQ                            24                       49
# f8MSbvd5JotxsFsS6fbl-Q                            22                       54
# g1phwUfq_-S8ZYTRqoG6iw                            28                       40
# i1WPpsuD5gyLppyB71vv6A                            37                       60
# i76ERS3jM111T3VMbi2yrQ                            20                       20
# kQRB8RNwd7cEMcURTS-I7A                            20                       20
# lML_PZePqlBBWpD1tqRdaA                            26                       44
# lstgSw6ejDzZRZLf446x8Q                            30                       49
# onp9X_9RRAEzA-yqdiSOcA                            19                       18
# p8ao29A31ijNwDXuAxQxjA                            29                       49
# pDOmFcUzaCzh2ETvx6z4BQ                            21                       48
# rWjFmr0hhi2w8IwMu162-Q                            22                       49
# ssr49VxAlvrBo7F7izQvXA                            28                       51
# vP6BGF8IqbXlLQiDP5n6dA                            29                       35
# vV57YWbrHqm1iylWmIdwVA                             5                       12
# wb_z1h7XR5IQhVRZHlMuLQ                            19                       20
# xtWIORPp-HG2LWtz5jQtiA                            28                       42
#
# question_category       Wait Times
# business_id
# -T5SfUI_QqgBrkq4D8Jn7w          15
# -pyobEWdpZ6jUp42f3I2xw          20
# -qk__vjJxfJrCWn3UaMv_Q          15
# 1hPvAr6D7yPpGbD_4RMqmQ          15
# 47Xuiwsv_YsJIm7Px_mNWQ          15
# 4WJqHhAq_CbtpzNiUuE9Eg          15
# 4e9tguRcMc4S5hzBlfC62A          20
# 5KS5b5-ip8znhJS_CYdzeQ          15
# 5X0M4waoFm4kH612ezVvtA          15
# 6imUPmHGgo9uknaoJXv79A          15
# 7McQCpcpjyAA_TaQPlsirg          15
# 9gPLN_mLR-kqwmcMe-QkOA          15
# 9piIhWbzbr-47RL-Rh63Iw          15
# DL5IVX_42Ra6DEq5d7NLrw          15
# Dh65GRW4FmOEjDv_UuPP4A          15
# JGVxKGvQEaMZ6O_2l0UucA          15
# JNBuXPEjE3eavcIUvUc49A          20
# Mfvk9uEEhdCqj8S2u7dWgQ          15
# O1kxISHZDJj55d4G2Xoevg          15
# OLSFUxfRCjLNPi49yOOrsQ          15
# ObDQDZEAyFCw8Dy803_O6Q          15
# RTwDv2oLE3gzAZlf63OPXA          22
# RuPk-ScXo4ycpdnAkpfoNg          15
# S2cKcdtOIDFyUfXYNPJUIw          15
# UQMUtySn2q9cSObiw5UVsw          20
# VwDrUaY7PPkvfD6M1dAVBQ          15
# WNqqyUtEmrqCBEHNV9sj5Q          15
# Wr2k0Vz8RbcumYulp-jIrA          15
# X4mouE_cMiwbfyCPZ_K-FA          15
# YH4q3-gWnglR1vstuEM8nA          15
# Ylc02u7HhDj0mnxeGt0y5Q          15
# bbL7sLg9gR3_08LZOriyTA          15
# cBiHULO8B4gTEav8eQJhuQ          15
# f8MSbvd5JotxsFsS6fbl-Q          15
# g1phwUfq_-S8ZYTRqoG6iw          15
# i1WPpsuD5gyLppyB71vv6A          15
# i76ERS3jM111T3VMbi2yrQ          20
# kQRB8RNwd7cEMcURTS-I7A          20
# lML_PZePqlBBWpD1tqRdaA          15
# lstgSw6ejDzZRZLf446x8Q          15
# onp9X_9RRAEzA-yqdiSOcA          19
# p8ao29A31ijNwDXuAxQxjA          15
# pDOmFcUzaCzh2ETvx6z4BQ          15
# rWjFmr0hhi2w8IwMu162-Q          15
# ssr49VxAlvrBo7F7izQvXA          15
# vP6BGF8IqbXlLQiDP5n6dA          16
# vV57YWbrHqm1iylWmIdwVA           5
# wb_z1h7XR5IQhVRZHlMuLQ          20
# xtWIORPp-HG2LWtz5jQtiA          15
#
# Restaurant Question Counts:
# business_id
# -T5SfUI_QqgBrkq4D8Jn7w    348
# -pyobEWdpZ6jUp42f3I2xw    200
# -qk__vjJxfJrCWn3UaMv_Q    342
# 1hPvAr6D7yPpGbD_4RMqmQ    334
# 47Xuiwsv_YsJIm7Px_mNWQ    355
# 4WJqHhAq_CbtpzNiUuE9Eg    356
# 4e9tguRcMc4S5hzBlfC62A    200
# 5KS5b5-ip8znhJS_CYdzeQ    334
# 5X0M4waoFm4kH612ezVvtA    338
# 6imUPmHGgo9uknaoJXv79A    336
# 7McQCpcpjyAA_TaQPlsirg    340
# 9gPLN_mLR-kqwmcMe-QkOA    337
# 9piIhWbzbr-47RL-Rh63Iw    359
# DL5IVX_42Ra6DEq5d7NLrw    340
# Dh65GRW4FmOEjDv_UuPP4A    342
# JGVxKGvQEaMZ6O_2l0UucA    335
# JNBuXPEjE3eavcIUvUc49A    200
# Mfvk9uEEhdCqj8S2u7dWgQ    360
# O1kxISHZDJj55d4G2Xoevg    341
# OLSFUxfRCjLNPi49yOOrsQ    385
# ObDQDZEAyFCw8Dy803_O6Q    337
# RTwDv2oLE3gzAZlf63OPXA    213
# RuPk-ScXo4ycpdnAkpfoNg    333
# S2cKcdtOIDFyUfXYNPJUIw    337
# UQMUtySn2q9cSObiw5UVsw    192
# VwDrUaY7PPkvfD6M1dAVBQ    339
# WNqqyUtEmrqCBEHNV9sj5Q    350
# Wr2k0Vz8RbcumYulp-jIrA    338
# X4mouE_cMiwbfyCPZ_K-FA    334
# YH4q3-gWnglR1vstuEM8nA    331
# Ylc02u7HhDj0mnxeGt0y5Q    337
# bbL7sLg9gR3_08LZOriyTA    341
# cBiHULO8B4gTEav8eQJhuQ    340
# f8MSbvd5JotxsFsS6fbl-Q    356
# g1phwUfq_-S8ZYTRqoG6iw    334
# i1WPpsuD5gyLppyB71vv6A    409
# i76ERS3jM111T3VMbi2yrQ    201
# kQRB8RNwd7cEMcURTS-I7A    200
# lML_PZePqlBBWpD1tqRdaA    341
# lstgSw6ejDzZRZLf446x8Q    352
# onp9X_9RRAEzA-yqdiSOcA    183
# p8ao29A31ijNwDXuAxQxjA    352
# pDOmFcUzaCzh2ETvx6z4BQ    336
# rWjFmr0hhi2w8IwMu162-Q    337
# ssr49VxAlvrBo7F7izQvXA    352
# vP6BGF8IqbXlLQiDP5n6dA    342
# vV57YWbrHqm1iylWmIdwVA    109
# wb_z1h7XR5IQhVRZHlMuLQ    200
# xtWIORPp-HG2LWtz5jQtiA    337
# dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="256a952d-12d9-4ecf-8ca2-57a1cdd1a6a9" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("256a952d-12d9-4ecf-8ca2-57a1cdd1a6a9")) {                    Plotly.newPlot(                        "256a952d-12d9-4ecf-8ca2-57a1cdd1a6a9",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eNumber of Questions=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3071,2434,2026,1560,1265,1229,1155,1021,812,772],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Service","Popular Dishes","Special Features\u002fEvents","Food Quality","Ambiance","Special Dietary Requirements","Price","Location\u002fAccessibility","Reservation Process","Wait Times"],"xaxis":"x","y":[3071,2434,2026,1560,1265,1229,1155,1021,812,772],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"out ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e247c4fc-5658-45e9-bc85-0ef5ef555ec4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e247c4fc-5658-45e9-bc85-0ef5ef555ec4")) {                    Plotly.newPlot(                        "e247c4fc-5658-45e9-bc85-0ef5ef555ec4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Service","Popular Dishes","Special Features\u002fEvents","Food Quality","Ambiance","Special Dietary Requirements","Price","Location\u002fAccessibility","Reservation Process","Wait Times"],"legendgroup":"","name":"","showlegend":true,"values":[3071,2434,2026,1560,1265,1229,1155,1021,812,772],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5277c514-0c07-4dd9-8556-3788db467dfe" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
NqqyUtEmrqCBEHNV9sj5Q","Wr2k0Vz8RbcumYulp-jIrA","X4mouE_cMiwbfyCPZ_K-FA","YH4q3-gWnglR1vstuEM8nA","Ylc02u7HhDj0mnxeGt0y5Q","bbL7sLg9gR3_08LZOriyTA","cBiHULO8B4gTEav8eQJhuQ","f8MSbvd5JotxsFsS6fbl-Q","g1phwUfq_-S8ZYTRqoG6iw","i1WPpsuD5gyLppyB71vv6A","i76ERS3jM111T3VMbi2yrQ","kQRB8RNwd7cEMcURTS-I7A","lML_PZePqlBBWpD1tqRdaA","lstgSw6ejDzZRZLf446x8Q","onp9X_9RRAEzA-yqdiSOcA","p8ao29A31ijNwDXuAxQxjA","pDOmFcUzaCzh2ETvx6z4BQ","rWjFmr0hhi2w8IwMu162-Q","ssr49VxAlvrBo7F7izQvXA","vP6BGF8IqbXlLQiDP5n6dA","vV57YWbrHqm1iylWmIdwVA","wb_z1h7XR5IQhVRZHlMuLQ","xtWIORPp-HG2LWtz5jQtiA"],"xaxis":"x","y":[348,200,342,334,355,356,200,334,338,336,340,337,359,340,342,335,200,360,341,385,337,213,333,337,192,339,350,338,334,331,337,341,340,356,334,409,201,200,341,352,183,352,336,337,352,342,109,200,337],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33 ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

train_list = []
val_list = []
test_list = []

unique_restaurants = df['business_id'].unique()

for biz_id in unique_restaurants:
    biz_df = df[df['business_id'] == biz_id].copy()
    categories = biz_df['question_category']

    try:
        train_df, temp_df = train_test_split(
            biz_df,
            test_size=0.3,
            stratify=categories,
            random_state=42
        )

        val_df, test_df = train_test_split(
            temp_df,
            test_size=2/3,
            stratify=temp_df['question_category'],
            random_state=42
        )

    except ValueError:
        train_df, temp_df = train_test_split(
            biz_df,
            test_size=0.3,
            random_state=42
        )
        val_df, test_df = train_test_split(
            temp_df,
            test_size=2/3,
            random_state=42
        )

    train_list.append(train_df)
    val_list.append(val_df)
    test_list.append(test_df)

train_final = pd.concat(train_list, axis=0, ignore_index=True)
val_final = pd.concat(val_list, axis=0, ignore_index=True)
test_final = pd.concat(test_list, axis=0, ignore_index=True)

print("Train size:", len(train_final))
print("Validation size:", len(val_final))
print("Test size:", len(test_final))
print("Total size:", len(train_final) + len(val_final) + len(test_final))

print("Train category distribution:")
print(train_final['question_category'].value_counts(normalize=True))

print("Val category distribution:")
print(val_final['question_category'].value_counts(normalize=True))

print("Test category distribution:")
print(test_final['question_category'].value_counts(normalize=True))

# %%
print("Overall distribution by restaurant:")
print(df['business_id'].value_counts())

print("\nTrain set distribution by restaurant:")
print(train_final['business_id'].value_counts())

print("\nValidation set distribution by restaurant:")
print(val_final['business_id'].value_counts())

print("\nTest set distribution by restaurant:")
print(test_final['business_id'].value_counts())

# %%
print("Train distribution by restaurant and category:")
print(train_final.groupby(['business_id', 'question_category']).size())

print("\nValidation distribution by restaurant and category:")
print(val_final.groupby(['business_id', 'question_category']).size())

print("\nTest distribution by restaurant and category:")
print(test_final.groupby(['business_id', 'question_category']).size())

# %%
train_final.to_csv("train_final.csv", index=False)
val_final.to_csv("val_final.csv", index=False)
test_final.to_csv("test_final.csv", index=False)
