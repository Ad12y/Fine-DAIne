# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth?tab=readme-ov-file#-installation-instructions).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# [NEW] Llama-3.1 8b, 70b & 405b are trained on a crazy 15 trillion tokens with 128K long context lengths!
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %%
# %%capture
# !pip install unsloth
# # Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %% [markdown]
# * We support Llama, Mistral, Phi-3, Gemma, Yi, DeepSeek, Qwen, TinyLlama, Vicuna, Open Hermes etc
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] We make Gemma-2 9b / 27b **2x faster**! See our [Gemma-2 9b notebook](https://colab.research.google.com/drive/1vIrqH5uYDQwsJ4-OO3DErvuv4pBgVwk4?usp=sharing)
# * [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)
# * [**NEW**] We make Mistral NeMo 12B 2x faster and fit in under 12GB of VRAM! [Mistral NeMo notebook](https://colab.research.google.com/drive/17d3U-CAIwzmbDRqbZ9NnpHxCkmXB6LZ0?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/340 [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0.05, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2024.12.4 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from datasets import Dataset
df = pd.read_csv("/content/drive/MyDrive/train_final.csv")

# %%
import pandas as pd
from datasets import Dataset
df_val = pd.read_csv("/content/drive/MyDrive/val_final.csv")

# %%
qa_data = {
    'question': df['question'].tolist(),
    'answer': df['answer'].tolist()
}

# %%
qa_val_data = {
    'question': df_val['question'].tolist(),
    'answer': df_val['answer'].tolist()
}

# %%
def format_qa(examples):
    texts = []
    for q, a in zip(examples['question'], examples['answer']):
        text = f"Question: {q}\nAnswer: {a}{tokenizer.eos_token}"
        texts.append(text)
    return {'text': texts}

# Create and process dataset
dataset = Dataset.from_dict(qa_data)
dataset = dataset.map(format_qa, batched=True)
val_dataset = Dataset.from_dict(qa_val_data)
val_dataset = val_dataset.map(format_qa, batched=True)
# Out:
# Map:   0%|          | 0/10721 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1529 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
import wandb

wandb.init(project="qa-model-training")
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    eval_dataset = val_dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        per_device_eval_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 3, # Set this for 1 full training run.
        #max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 300,
        evaluation_strategy="steps",
        eval_steps=300,
        save_strategy="steps",
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "wandb", # Use this for WandB etc
    ),
)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241212_033906-0qfw0gdn</code>
# Syncing run <strong><a href='https://wandb.ai/aditya12singhal-rutgers-university/qa-model-training/runs/0qfw0gdn' target="_blank">different-disco-48</a></strong> to <a href='https://wandb.ai/aditya12singhal-rutgers-university/qa-model-training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/aditya12singhal-rutgers-university/qa-model-training' target="_blank">https://wandb.ai/aditya12singhal-rutgers-university/qa-model-training</a>
#  View run at <a href='https://wandb.ai/aditya12singhal-rutgers-university/qa-model-training/runs/0qfw0gdn' target="_blank">https://wandb.ai/aditya12singhal-rutgers-university/qa-model-training/runs/0qfw0gdn</a>
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Map (num_proc=2):   0%|          | 0/10721 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/1529 [00:00<?, ? examples/s]

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.564 GB.
# 4.52 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 10,721 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 4,020
#  "-____-"     Number of trainable parameters = 41,943,040
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#     <div>
#
#       <progress value='2614' max='4020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2614/4020 1:56:18 < 1:02:36, 0.37 it/s, Epoch 1.95/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>1.269200</td>
#       <td>1.074370</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.064200</td>
#       <td>1.015147</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.022600</td>
#       <td>0.977537</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.978800</td>
#       <td>0.955358</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.884100</td>
#       <td>0.958873</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.828800</td>
#       <td>0.948668</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.815700</td>
#       <td>0.934602</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.806600</td>
#       <td>0.928553</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='4020' max='4020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4020/4020 3:00:19, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>1.269200</td>
#       <td>1.074370</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.064200</td>
#       <td>1.015147</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.022600</td>
#       <td>0.977537</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.978800</td>
#       <td>0.955358</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.884100</td>
#       <td>0.958873</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.828800</td>
#       <td>0.948668</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.815700</td>
#       <td>0.934602</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.806600</td>
#       <td>0.928553</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.797000</td>
#       <td>0.969246</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.591600</td>
#       <td>1.000131</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.585400</td>
#       <td>0.995917</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.581300</td>
#       <td>0.991738</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.583300</td>
#       <td>0.988536</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
import os
save_directory = "/content/drive/MyDrive/Llama_model"
os.makedirs(save_directory, exist_ok=True)

# Save model and tokenizer
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)
# Out:
# ('/content/drive/MyDrive/Llama_model/tokenizer_config.json',
#  '/content/drive/MyDrive/Llama_model/special_tokens_map.json',
#  '/content/drive/MyDrive/Llama_model/tokenizer.json')

# %%
import pandas as pd
from datasets import Dataset
df_eval = pd.read_csv("/content/drive/MyDrive/test_final.csv")

# %%
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "/content/drive/MyDrive/Llama_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

FastLanguageModel.for_inference(model)  # Enable native 2x faster inference

predictions = []
batch_size = 300
total_questions = len(df_eval)
num_batches = (total_questions + batch_size - 1) // batch_size  # Ceiling division

print(f"Total questions to process: {total_questions}")
print(f"Number of batches: {num_batches}")

for batch_idx in range(0, total_questions, batch_size):
    # Get current batch
    start_idx = batch_idx
    end_idx = min(batch_idx + batch_size, total_questions)
    batch_questions = df_eval['question'][start_idx:end_idx]

    print(f"\nProcessing batch {(batch_idx // batch_size) + 1}/{num_batches}")
    print(f"Questions {start_idx + 1} to {end_idx}")

    batch_predictions = []
    for question in batch_questions:
        qa_prompt = f"Question: {question}\nAnswer:"

        inputs = tokenizer(
            [qa_prompt],
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=512
        ).to("cuda")

        outputs = model.generate(
            **inputs,
            max_new_tokens=64,
            use_cache=True
        )

        response = tokenizer.batch_decode(outputs)[0]
        clean_response = response.split('Answer:')[1].strip().replace('<|eot_id|>', '').replace('</s>', '').replace('<|end_of_text|>', '').strip()
        print(question)
        print(clean_response)
        print(" ")
        batch_predictions.append(clean_response)

    predictions.extend(batch_predictions)

    # Save intermediate results
    temp_df = df_eval.copy()
    temp_df['predicted_answer'] = predictions + [None] * (len(df_eval) - len(predictions))
    temp_df.to_csv(f'/content/drive/MyDrive/qa_1_lla_results_batch_{(batch_idx // batch_size) + 1}.csv', index=False)

# Add all predictions to main DataFrame
df_eval['predicted_answer'] = predictions

# Save final results
df_eval.to_csv('/content/drive/MyDrive/qa_1_lla_results_final.csv', index=False)
print("\nFinal results saved")
print(f"Total questions processed: {len(predictions)}")
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2024.12.4 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.
# Total questions to process: 3095
# Number of batches: 11
#
# Processing batch 1/11
# Questions 1 to 300
# Does Adelphia Restaurant & Events serve Egyptian food?
# Adelphia Restaurant & Events does not offer egyptian.
#
# How attentive are the staff at Adelphia Restaurant & Events?
# The staff at Adelphia Restaurant & Events are described as very attentive and professional. One reviewer mentioned that the staff was attentive without being intrusive, while another reviewer highlighted the staff's professionalism.
#
# Does Adelphia Restaurant & Events have vegan options?
# Adelphia Restaurant & Events may not accommodate vegan dietary requirements.
#
# What fire-roasted specialties does Adelphia Restaurant & Events offer?
# They offer fire-roasted lamb chops, fire-grilled filet mignon, and wood-grilled salmon.
#
# Does Adelphia Restaurant & Events have spa services?
# Adelphia Restaurant & Events does not offer beauty & spas.
#
# How is the traffic around Adelphia Restaurant & Events?
# Based on the reviews, Adelphia Restaurant & Events is described as a "great place to go when you don't want to go into the city" and "definitely worth the drive." This suggests that the restaurant is located in a convenient location and is worth traveling to.
#
# What's the price difference between regular and stuffed shrimp at Adelphia Restaurant & Events?
# Jumbo stuffed shrimp is $6 more at $26.00 compared to regular shrimp at $20.00.
#
# Do they have quick service at Adelphia Restaurant & Events?
# Based on the reviews, the service at Adelphia Restaurant & Events seems to vary. One reviewer mentioned that the bartenders were very personable and the service was quick, while another reviewer experienced slow service with long wait times for drinks and food.
#
# How are the seasonal specials at Adelphia Restaurant & Events?
# Based on the reviews, Adelphia Restaurant & Events offers great specials. One reviewer mentioned that they have great specials, while another reviewer specifically mentioned that they have great specials.
#
# Does Adelphia Restaurant & Events have nightlife?
# Adelphia Restaurant & Events offers nightlife.
#
# Is Adelphia Restaurant & Events closed on Saturdays?
# Adelphia Restaurant & Events is not closed on Saturday.
#
# Does Adelphia Restaurant & Events accept credit cards?
# The restaurant accepts credit cards.
#
# Is the staff professional at Adelphia Restaurant & Events?
# Based on the reviews, the staff at Adelphia Restaurant & Events is described as professional. One reviewer mentioned that the staff is always professional and courteous, while another reviewer specifically praised the banquet staff for being attentive and professional during their daughter's wedding.
#
# How are the prices at Adelphia Restaurant & Events?
# Based on the reviews, the prices at Adelphia Restaurant & Events are described as very reasonable. One reviewer mentioned that the lunch prices are very reasonable, while another reviewer noted that the prices for drinks were not on the menu but were still reasonable.
#
# Does Adelphia Restaurant & Events serve dinner?
# Adelphia Restaurant & Events does serve dinner.
#
# Is Adelphia Restaurant & Events easy to find?
# Based on the reviews, Adelphia Restaurant & Events seems to be easy to find as it is described as a "big white building" and is mentioned to be a popular spot for nightlife.
#
# Is Adelphia Restaurant & Events good for kids?
# The restaurant is good for kids.
#
# How is the value for money at Adelphia Restaurant & Events?
# Based on the reviews, the value for money at Adelphia Restaurant & Events seems to vary. One reviewer mentioned that the lunch special offered good value, while another reviewer felt that the price for a drink was too high. Additionally, one reviewer mentioned that the Sunday brunch provided good value for the price.
#
# How is the overall food quality at Adelphia Restaurant & Events?
# Based on the reviews, the overall food quality at Adelphia Restaurant & Events seems to be inconsistent. One reviewer mentioned that the food was good but not great, while another reviewer specifically mentioned that the food was cold and of poor quality. This suggests that the food quality may vary depending on the day or time of visit
#
# Does Adelphia Restaurant & Events serve Japanese food?
# Adelphia Restaurant & Events does not offer japanese.
#
# Is Adelphia Restaurant & Events a full-service restaurant?
# Adelphia Restaurant & Events offers restaurants service. Staff is professional.
#
# How is the flavor of the food at Adelphia Restaurant & Events?
# Based on the reviews, the flavor of the food at Adelphia Restaurant & Events seems to be inconsistent. One reviewer mentioned that their baked potato had no flavor, while another reviewer found the chicken to be dry and lacking in flavor. However, the salad was described as fresh and tasty.
#
# How is Adelphia Restaurant & Events's Mediterranean Sampler prepared?
# It combines hummus, tzatziki, stuffed grape leaves, feta cheese, and olives.
#
# Does Adelphia Restaurant & Events serve Indian food?
# Adelphia Restaurant & Events does not offer indian.
#
# Does Adelphia Restaurant & Events serve steaks?
# Adelphia Restaurant & Events does not offer steakhouses.
#
# What premium champagne options does Adelphia Restaurant & Events offer?
# They offer premium champagnes including Dom Perignon and Moet & Chandon Brut Imperial Brut.
#
# Is Adelphia Restaurant & Events good for late night dining?
# The restaurant is not particularly good for late night dining.
#
# Is it cozy at Adelphia Restaurant & Events?
# Based on the reviews, Adelphia Restaurant & Events has a large venue with different sections, including a patio and outdoor tiki bar. One reviewer mentioned that the outdoor area was nice, while another reviewer noted that the indoor area was not particularly impressive. Overall, the atmosphere may vary depending on the section you are in
#
# Does Adelphia Restaurant & Events serve salads?
# Adelphia Restaurant & Events does not offer salad.
#
# Does Adelphia Restaurant & Events serve Mexican food?
# Adelphia Restaurant & Events does not offer mexican.
#
# Does Adelphia Restaurant & Events serve Italian food?
# Adelphia Restaurant & Events does not offer italian.
#
# What seafood options does Adelphia Restaurant & Events offer without shellfish?
# They offer Atlantic Salmon, English Pub Fish & Chips (cod), and Shrimp & Chicken gumbo.
#
# How is the quality of ingredients at Adelphia Restaurant & Events?
# Based on the reviews, the quality of ingredients at Adelphia Restaurant & Events seems to be inconsistent. One reviewer mentioned that the chicken and waffles had good ingredients, while another reviewer found the ingredients in the stuffed chicken to be subpar, with dry breadcrumbs and a strange sauce.
#
# Is Adelphia Restaurant & Events closed on Sundays?
# Adelphia Restaurant & Events is not closed on Sunday.
#
# Does Adelphia Restaurant & Events have a wine bar?
# Adelphia Restaurant & Events does not provide wine bars service.
#
# Do they hold reservations at Adelphia Restaurant & Events?
# Based on the reviews, it seems that Adelphia Restaurant & Events does hold reservations. One reviewer mentioned having reservations for a large party and being seated in a specific room. However, there was an issue with the tables being too small and the party size being too large for the room.
#
# Does Adelphia Restaurant & Events serve baked goods?
# Adelphia Restaurant & Events does not offer bakeries.
#
# Is Adelphia Restaurant & Events a diner?
# Adelphia Restaurant & Events does not provide diners service.
#
# How are the local favorites at Adelphia Restaurant & Events?
# Based on the reviews, the local favorites at Adelphia Restaurant & Events include the homemade desserts and the overall food quality. Reviewers mentioned that the desserts are delicious and the food is good, indicating that these items are popular among customers.
#
# How long is the wait at Adelphia Restaurant & Events?
# Based on the reviews, the wait time at Adelphia Restaurant & Events can vary. In one review from 2019, the customer mentioned a 45-minute wait but was seated in less than 15 minutes. However, in another review from 2016, the customer experienced a 3-hour wait on a
#
# What's the price difference between house and premium wines at Adelphia Restaurant & Events?
# House wines are $9/glass or $35/carafe, while premium wines start at $12/glass and $50/carafe.
#
# Would you describe the ambience at Adelphia Restaurant & Events as divey?
# The ambience at the restaurant is not divey.
#
# How is the customer service at Adelphia Restaurant & Events?
# Based on the reviews, the customer service at Adelphia Restaurant & Events seems to be a mixed bag. One reviewer mentioned that the service was "very good" and another reviewer stated that the service was "good." However, there were also complaints about the lack of availability of certain menu items and issues with the drink
#
# What vegan options does Adelphia Restaurant & Events mark on their menu?
# They mark several items vegan including the Meatless Cheesesteak Sandwich and Vegan Quesadilla.
#
# Do they have good deals at Adelphia Restaurant & Events?
# Based on the reviews, Adelphia Restaurant & Events offers good deals during happy hour. One reviewer mentioned that the drink prices were great and another reviewer highlighted the good deals on food during happy hour.
#
# Is there a parking lot at Adelphia Restaurant & Events?
# Yes, there is a parking lot at Adelphia Restaurant & Events. One reviewer mentioned that the parking lot was almost full on a Saturday night, indicating that there is ample parking available.
#
# Is Adelphia Restaurant & Events a gastropub?
# Adelphia Restaurant & Events does not provide gastropubs service.
#
# Does Adelphia Restaurant & Events have vegetarian options?
# Adelphia Restaurant & Events may not accommodate vegetarian dietary requirements.
#
# Does Adelphia Restaurant & Events serve lunch?
# Adelphia Restaurant & Events does serve lunch.
#
# Is Adelphia Restaurant & Events wheelchair accessible?
# Based on the reviews, there is no specific mention of Adelphia Restaurant & Events being wheelchair accessible. However, one reviewer did mention that the restaurant is good for large groups, which could imply that they may be accommodating to different needs such as wheelchair accessibility.
#
# How is Adelphia Restaurant & Events's Chicken Siena prepared?
# It's grilled chicken breast topped with sautéed mushrooms, bacon, Swiss, and creamy sauce.
#
# Does Adelphia Restaurant & Events serve New American cuisine?
# Adelphia Restaurant & Events does not offer american (new).
#
# Does Adelphia Restaurant & Events have a tiki bar?
# Adelphia Restaurant & Events does not provide tiki bars service.
#
# Is there live music at Adelphia Restaurant & Events?
# Yes, according to the reviews, Adelphia Restaurant & Events has live music at the Pour House. One reviewer specifically mentioned that the Pour House has live music, which adds to the ambiance of the place.
#
# Does Adelphia Restaurant & Events have vegetarian options?
# Adelphia Restaurant & Events may not accommodate vegetarian dietary requirements.
#
# Does Adelphia Restaurant & Events serve Szechuan food?
# Adelphia Restaurant & Events does not offer szechuan.
#
# Is it crowded at Adelphia Restaurant & Events?
# Based on the reviews, Adelphia Restaurant & Events can get crowded, especially on Friday nights. One reviewer mentioned that the bar area was packed, but they were still able to find seating. Another reviewer noted that the place was crowded with a mix of young and older people.
#
# Is there entertainment at Adelphia Restaurant & Events?
# Yes, there is entertainment at Adelphia Restaurant & Events. One reviewer mentioned that they have live entertainment at the bar, which adds to the experience. Another reviewer mentioned that the entertainment was great and they had a great time dancing.
#
# How is the music at Adelphia Restaurant & Events?
# Based on the reviews, the music at Adelphia Restaurant & Events is described as awesome and enjoyable. One reviewer mentioned that the DJ was awesome and kept the party going, while another reviewer enjoyed the music during their lunch experience.
#
# Is there bike parking at Adelphia Restaurant & Events?
# Based on the reviews, there is no mention of bike parking at Adelphia Restaurant & Events. The reviews mainly focus on the good food, friendly staff, and live entertainment.
#
# How is the service at Adelphia Restaurant & Events?
# The service at Adelphia Restaurant & Events is described as excellent and professional. Reviewers mentioned that the staff is attentive, courteous, and goes above and beyond to ensure a great dining experience. One reviewer specifically mentioned the "fantastic service" they received during a holiday family dinner.
#
# How's the wait at the bar at Adelphia Restaurant & Events?
# Based on the reviews, the wait at the bar at Adelphia Restaurant & Events can be quite long. One reviewer mentioned waiting 10 minutes without any service, while another reviewer mentioned waiting 15-20 minutes without any attention from the bartenders.
#
# Does Adelphia Restaurant & Events have private rooms?
# Based on the reviews, Adelphia Restaurant & Events does have private rooms. One reviewer mentioned having a private room for their bachelor party and praised the service and food in the private room. Another reviewer mentioned that they have multiple private rooms of different sizes available.
#
# Would you describe the ambience at Adelphia Restaurant & Events as casual?
# The ambience at the restaurant is casual.
#
# Do they have a waiting list at Adelphia Restaurant & Events?
# Yes, based on the reviews, Adelphia Restaurant & Events has a waiting list. One reviewer mentioned that there was a 45-minute wait for a table, while another reviewer mentioned waiting 15 minutes for a table and being seated in a different location.
#
# Is Adelphia Restaurant & Events open on Tuesdays?
# Adelphia Restaurant & Events is open on Tuesday.
#
# Do they confirm reservations at Adelphia Restaurant & Events?
# Based on the reviews, it seems that Adelphia Restaurant & Events does confirm reservations. One reviewer mentioned that they had made a reservation via OpenTable and another mentioned that they had made a reservation for Easter brunch. However, there were still issues with seating and service on time.
#
# Are there special holiday events at Adelphia Restaurant & Events?
# Yes, based on the reviews, Adelphia Restaurant & Events hosts special events, such as the Christmas family dinner mentioned in one of the reviews. The reviewer mentioned having a wonderful time with their family at the event.
#
# Does Marcello's Coal Fired Restaurant & Pizza serve Lebanese food?
# Marcello's Coal Fired Restaurant & Pizza does not offer lebanese.
#
# How fast is the food service at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the food service at Marcello's Coal Fired Restaurant & Pizza is described as great and always a pleasure. One reviewer mentioned that the service was great, and another reviewer specifically praised the service at the restaurant.
#
# How long between courses at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the service at Marcello's Coal Fired Restaurant & Pizza seems to vary. One reviewer mentioned that the service was very good, while another reviewer noted that the service was a little slow. It appears that there may be inconsistency in the timing between courses at this restaurant.
#
# Are there any differences in the hours of operation at Marcello's Coal Fired Restaurant & Pizza across the week?
# Marcello's Coal Fired Restaurant & Pizza has varying hours across the week. Please check specific days for detailed hours.
#
# Are there seasonal events at Marcello's Coal Fired Restaurant & Pizza?
# Yes, based on the reviews, Marcello's Coal Fired Restaurant & Pizza is a popular spot for special events such as showers and parties. One reviewer mentioned that the restaurant is a "great spot for special events" and another reviewer mentioned having a work holiday party there with a group of 15 people.
#
# How many Garlic Knots come in an order?
# 6 knots
#
# How is the overall food quality at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the overall food quality at Marcello's Coal Fired Restaurant & Pizza is excellent. Reviewers specifically mentioned the great pizza with fresh ingredients, delicious entrees like the NY strip and salmon, and yummy appetizers such as the fried calamari and clams. Additionally, the restaurant offers a great selection
#
# Is there good signage for Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, there is no mention of signage for Marcello's Coal Fired Restaurant & Pizza. However, one reviewer did mention that the restaurant has a huge bar, which could indicate a prominent location that may not require elaborate signage.
#
# Does Marcello's Coal Fired Restaurant & Pizza serve beer?
# Marcello's Coal Fired Restaurant & Pizza does not provide beer service.
#
# How is the traffic around Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, Marcello's Coal Fired Restaurant & Pizza is located in a strip mall, which suggests that the traffic around the restaurant is likely busy due to the nearby shopping center. One reviewer mentioned that the restaurant is in a great location, which could imply that it is easily accessible and visible to a large number
#
# Is Marcello's Coal Fired Restaurant & Pizza closed on Sundays?
# Marcello's Coal Fired Restaurant & Pizza is not closed on Sunday.
#
# How busy is Marcello's Coal Fired Restaurant & Pizza at dinner?
# Based on the reviews, Marcello's Coal Fired Restaurant & Pizza can be quite busy during dinner service. One reviewer mentioned that the restaurant was "very busy for a Tuesday night," while another reviewer noted that it was "busy for a Friday night."
#
# Is there street parking near Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, parking near Marcello's Coal Fired Restaurant & Pizza is limited and can be difficult to find. One reviewer mentioned that parking was at a premium and they had to park down the street. Another reviewer noted that there were only 4 or 5 spots in the front and limited parking in the back
#
# Does Marcello's Coal Fired Restaurant & Pizza serve wine and spirits?
# Marcello's Coal Fired Restaurant & Pizza does not provide wine & spirits service.
#
# Is the food fresh at Marcello's Coal Fired Restaurant & Pizza?
# Yes, according to the reviews, the food at Marcello's Coal Fired Restaurant & Pizza is described as fresh. One reviewer mentioned that the salad was fresh with a light dressing, while another reviewer praised the pizza as being made with fresh ingredients and cooked to perfection.
#
# How are the weekend prices at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the prices at Marcello's Coal Fired Restaurant & Pizza on the weekend are considered reasonable. One reviewer mentioned that the prices were not overly inflated, and another reviewer noted that the prices were very reasonable for the amount of food provided.
#
# What makes Marcello's Coal Fired Restaurant & Pizza's Arancini special?
# They're made with Calabrian long hot peppers, mozzarella, and Italian herb seasoned rice balls served with house marinara.
#
# Is there live music at Marcello's Coal Fired Restaurant & Pizza?
# Yes, according to the reviews, Marcello's Coal Fired Restaurant & Pizza has live music. One reviewer mentioned that they enjoy the live music at the restaurant, while another reviewer specifically mentioned the live band and how they enjoyed the music.
#
# Is Marcello's Coal Fired Restaurant & Pizza good for kids?
# The restaurant is good for kids.
#
# Does Marcello's Coal Fired Restaurant & Pizza offer catering?
# Marcello's Coal Fired Restaurant & Pizza does not provide caterers service.
#
# Does Marcello's Coal Fired Restaurant & Pizza offer event planning?
# Marcello's Coal Fired Restaurant & Pizza does not offer event planning & services.
#
# Does Marcello's Coal Fired Restaurant & Pizza have nightlife?
# Marcello's Coal Fired Restaurant & Pizza offers nightlife.
#
# Is there entertainment at Marcello's Coal Fired Restaurant & Pizza?
# Yes, there is entertainment at Marcello's Coal Fired Restaurant & Pizza. One reviewer mentioned that they had a great time with their fiancé, watching a couple play pool and enjoying the atmosphere.
#
# Do they take weekend reservations at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, it seems that Marcello's Coal Fired Restaurant & Pizza does take reservations, but there have been complaints about overbooking and long wait times even with a reservation. One reviewer mentioned having a reservation but still waiting 45 minutes to be seated, while another reviewer mentioned having a reservation for 8:
#
# What's good for sharing at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the brick oven pizza at Marcello's Coal Fired Restaurant & Pizza is highly recommended for sharing. One reviewer mentioned that it was the best they ever had, while another reviewer enjoyed it with their wife. Additionally, the mussels white and calamari appetizers were also mentioned as great options for sharing
#
# How attentive are the staff at Marcello's Coal Fired Restaurant & Pizza?
# The staff at Marcello's Coal Fired Restaurant & Pizza are described as very attentive in both reviews. One reviewer mentioned that the wait staff was very attentive, while another reviewer specifically highlighted the wait staff as being very attentive.
#
# Does Marcello's Coal Fired Restaurant & Pizza have vegetarian options?
# Marcello's Coal Fired Restaurant & Pizza may not accommodate vegetarian dietary requirements.
#
# What pasta is served with the Kids Chicken Parm?
# The Kids Chicken Parm comes with spaghetti pasta.
#
# Is there free parking at Marcello's Coal Fired Restaurant & Pizza?
# Yes, there is free valet parking available at Marcello's Coal Fired Restaurant & Pizza. One reviewer mentioned that they offer free valet parking, which is a nice touch.
#
# What's good for dinner at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the brick oven pizza at Marcello's Coal Fired Restaurant & Pizza is highly recommended. One reviewer mentioned that it was the best they've had in the USA, while another reviewer specifically praised the margherita pizza with fresh basil and the pepperoni pie. Additionally, the chicken and eggplant parm
#
# How is the Flounder Franchese prepared at Marcello's Coal Fired Restaurant & Pizza?
# The Flounder Franchese is prepared with lemon wedge.
#
# Do they have combo deals at Marcello's Coal Fired Restaurant & Pizza?
# Yes, Marcello's Coal Fired Restaurant & Pizza offers combo deals. One reviewer mentioned getting a deal on their Facebook page that included 2 large pies and 2 salads for $35. Another reviewer mentioned a deal on Groupon for a family of four to eat at the restaurant.
#
# How is the customer service at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the customer service at Marcello's Coal Fired Restaurant & Pizza seems to be excellent. One reviewer mentioned that the service was attentive and another reviewer specifically praised the barback Tony for being amazing and helpful.
#
# Does Marcello's Coal Fired Restaurant & Pizza have background music?
# The restaurant does not have background music.
#
# Is it cozy at Marcello's Coal Fired Restaurant & Pizza?
# Yes, according to the reviews, Marcello's Coal Fired Restaurant & Pizza has a cozy atmosphere. One reviewer mentioned that the restaurant has a cozy and clean atmosphere, while another reviewer described it as a cozy little spot.
#
# Does Marcello's Coal Fired Restaurant & Pizza serve sandwiches?
# Marcello's Coal Fired Restaurant & Pizza does not offer sandwiches.
#
# Does Marcello's Coal Fired Restaurant & Pizza serve Traditional American food?
# Marcello's Coal Fired Restaurant & Pizza does not offer american (traditional).
#
# How is the music at Marcello's Coal Fired Restaurant & Pizza?
# The music at Marcello's Coal Fired Restaurant & Pizza is described as great and enjoyable. One reviewer mentioned that the live music was great, while another reviewer noted that the music was enjoyable and added to the overall experience of dining at the restaurant.
#
# When is Marcello's Coal Fired Restaurant & Pizza open on Saturdays?
# Marcello's Coal Fired Restaurant & Pizza is open on Saturday from 11:00-23:00
#
# Does Marcello's Coal Fired Restaurant & Pizza serve halal food?
# Marcello's Coal Fired Restaurant & Pizza may not accommodate halal dietary requirements.
#
# How is the price range at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the price range at Marcello's Coal Fired Restaurant & Pizza is considered reasonable. One reviewer mentioned that they ordered a large meal and only paid $15, which they found to be a good deal. Another reviewer noted that the prices for drinks were not posted on the menu, indicating a potential lack
#
# What unique dessert option does Marcello's offer that incorporates a popular hazelnut spread?
# They create a Nutella Stromboli dessert with cannoli cream & chocolate chips.
#
# Are the Arancini at Marcello's Coal Fired Restaurant & Pizza vegetarian?
# The Arancini is vegetarian-friendly.
#
# Is Marcello's Coal Fired Restaurant & Pizza closed on Thursdays?
# Marcello's Coal Fired Restaurant & Pizza is not closed on Thursday.
#
# What are the best dishes at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the best dishes at Marcello's Coal Fired Restaurant & Pizza are the mussels white, chicken Francese, and the pizza, specifically the margherita pie. Reviewers mentioned that the mussels white was delicious and plentiful, the chicken Francese was perfectly made, and the pizza was described
#
# Do they confirm reservations at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, Marcello's Coal Fired Restaurant & Pizza does confirm reservations. One reviewer mentioned making reservations for Valentine's Day and being seated immediately upon arrival. Another reviewer mentioned making reservations for a birthday party and being accommodated with a table in a specific location.
#
# What's the must-try dish at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the must-try dish at Marcello's Coal Fired Restaurant & Pizza is the traditional tomato pie. One reviewer specifically mentioned it as a must-try pizza.
#
# Does Marcello's Coal Fired Restaurant & Pizza have music videos?
# The restaurant does not have music videos.
#
# Do they refill drinks regularly at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, it seems that drink refills were not done regularly at Marcello's Coal Fired Restaurant & Pizza. In one review, the customer mentioned that they had to wait 40 minutes for a table and 20 minutes for someone to take their drink order. Another reviewer mentioned that they had to ask for
#
# Is Marcello's Coal Fired Restaurant & Pizza open on Fridays?
# Marcello's Coal Fired Restaurant & Pizza is open on Friday.
#
# Do they cater from Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, Marcello's Coal Fired Restaurant & Pizza offers catering services. One reviewer mentioned that they used Marcello's for their wedding catering and were very satisfied with the food and service. Another reviewer mentioned that they catered for 75 people and the food was excellent.
#
# What is the price range for appetizers (Antipasti) at Marcello's?
# $6.00 - $14.00
#
# Is Marcello's Coal Fired Restaurant & Pizza a sports bar?
# Marcello's Coal Fired Restaurant & Pizza does not provide sports bars service.
#
# How is the Ahi Tuna prepared in Marcello's Coal Fired Restaurant & Pizza's salad?
# The Ahi Tuna is seared rare and served over field greens with goat cheese, sliced cherry tomatoes, and balsamic vinaigrette.
#
# What are the breakfast hours at Marcello's Coal Fired Restaurant & Pizza?
# Marcello's Coal Fired Restaurant & Pizza does not serve breakfast.
#
# Does Marcello's Coal Fired Restaurant & Pizza have spa services?
# Marcello's Coal Fired Restaurant & Pizza does not offer beauty & spas.
#
# Do they have low-carb dishes at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, Marcello's Coal Fired Restaurant & Pizza offers a variety of dishes, including salads and chicken dishes, which could potentially be considered low-carb options. However, there is no specific mention of low-carb dishes in the reviews provided.
#
# How are the main dishes at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the main dishes at Marcello's Coal Fired Restaurant & Pizza are highly praised. Reviewers mentioned enjoying the mushroom ravioli, steak, and chicken dishes, with one reviewer specifically mentioning that the steak is the best they've ever had. Additionally, the family style meal option was recommended for sharing
#
# Are the desserts at Marcello's Coal Fired Restaurant & Pizza made in-house?
# Yes, the desserts like Tiramisu and Cannoli are freshly made in-house.
#
# Does Marcello's Coal Fired Restaurant & Pizza serve Italian food?
# Marcello's Coal Fired Restaurant & Pizza offers italian.
#
# Can you modify bookings at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, it seems that modifying bookings at Marcello's Coal Fired Restaurant & Pizza may be difficult. One reviewer mentioned that when they arrived for their reservation, they were told they didn't have one despite confirming earlier in the day. Another reviewer mentioned that when they asked for a different table because of noise and
#
# Is the food worth the price at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, the food at Marcello's Coal Fired Restaurant & Pizza is considered worth the price by one reviewer who mentioned that the pizza was well worth the price. However, another reviewer felt that the restaurant was overpriced for the quality of food they received.
#
# Does Marcello's Coal Fired Restaurant & Pizza offer gluten-free pasta options?
# Yes, they offer gluten-free penne for $2.00 as an add-on.
#
# Does Marcello's Coal Fired Restaurant & Pizza serve Japanese pub food?
# Marcello's Coal Fired Restaurant & Pizza does not offer izakaya.
#
# Would you describe the ambience at Marcello's Coal Fired Restaurant & Pizza as upscale?
# The ambience at the restaurant is not upscale.
#
# Is it crowded at Marcello's Coal Fired Restaurant & Pizza?
# Based on the reviews, Marcello's Coal Fired Restaurant & Pizza can get crowded on weekends. One reviewer mentioned that the bar area is packed on weekends, but they were still able to find seating for a before dinner drink. Another reviewer mentioned that the restaurant was busy during their visit, but they were able to get a
#
# Would you describe the ambience at Marcello's Coal Fired Restaurant & Pizza as intimate?
# The ambience at the restaurant is not intimate.
#
# When is Marcello's Coal Fired Restaurant & Pizza open on Mondays?
# Marcello's Coal Fired Restaurant & Pizza is closed on M
#
# Is Marcello's Coal Fired Restaurant & Pizza in a hotel?
# Marcello's Coal Fired Restaurant & Pizza does not offer hotels.
#
# What's the price range for desserts at Marcello's Coal Fired Restaurant & Pizza?
# Desserts range from $8.00 for Cannoli & Pizelle Napoleon to $9.00 for Tiramisu or Gelato.
#
# Does Il Fiore Restaurant serve Middle Eastern food?
# Il Fiore Restaurant does not offer middle eastern.
#
# Is Il Fiore Restaurant a gastropub?
# Il Fiore Restaurant does not provide gastropubs service.
#
# How is the hospitality at Il Fiore Restaurant?
# Based on the reviews, the hospitality at Il Fiore Restaurant is excellent. Reviewers mentioned that the staff is very attentive, friendly, and provides a great dining experience. One reviewer specifically mentioned that the staff are "extremely friendly" and another mentioned that the service was "great."
#
# Is Il Fiore Restaurant good for late night dining?
# The restaurant is not particularly good for late night dining.
#
# Does Il Fiore Restaurant have a tiki bar?
# Il Fiore Restaurant does not provide tiki bars service.
#
# Is the Vitello Marsala a popular dish at Il Fiore Restaurant?
# Yes, the Vitello Marsala is loved for its Veal scaloppini with mushrooms, shrimp, and fresh tomatoes in a sweet marsala wine sauce..
#
# Does Il Fiore Restaurant serve Brazilian food?
# Il Fiore Restaurant does not offer brazilian.
#
# Do they confirm reservations at Il Fiore Restaurant?
# Based on the reviews, it seems that Il Fiore Restaurant does not confirm reservations. One reviewer mentioned that they were told to call ahead but still had to wait 40 minutes despite seeing empty tables. Another reviewer mentioned that they were told to wait 15 minutes but ended up waiting over 30 minutes.
#
# Is the Insalata Caesar Salad a popular dish at Il Fiore Restaurant?
# Yes, the Insalata Caesar Salad is loved for its Romain lettuce, croutons, parmesan cheese, garlic, lemon.
#
# Does Il Fiore Restaurant have vegetarian options?
# Il Fiore Restaurant may not accommodate vegetarian dietary requirements.
#
# How are the local favorites at Il Fiore Restaurant?
# Based on the reviews, the local favorites at Il Fiore Restaurant include the mushroom appetizer, pasta with vodka sauce, and the chocolate chip cake for dessert. Reviewers specifically mentioned these dishes as their favorites and highly recommended them.
#
# When is Il Fiore Restaurant open on Tuesdays?
# Il Fiore Restaurant is open on Tuesday from 16:30-22:00
#
# Can you call for reservations at Il Fiore Restaurant?
# Yes, according to the reviews, it is recommended to call ahead for reservations at Il Fiore Restaurant to avoid a long wait. One reviewer mentioned that they called ahead and were able to get a table right away.
#
# How are the weekend prices at Il Fiore Restaurant?
# Based on the reviews, the weekend prices at Il Fiore Restaurant seem to be reasonable. One reviewer mentioned that the prices were reasonable for the quality of food provided during their lunch visit on a weekend. Another reviewer mentioned that the prices were a little high, but they felt it was worth it for the great food and service
#
# Is Il Fiore Restaurant closed on Wednesdays?
# Il Fiore Restaurant is not closed on Wednesday.
#
# Does Il Fiore Restaurant serve salads?
# Il Fiore Restaurant does not offer salad.
#
# Is the Vitello Marsala at Il Fiore Restaurant gluten-free?
# The Vitello Marsala is gluten-free.
#
# Is Il Fiore Restaurant closed on Mondays?
# Il Fiore Restaurant is closed on Monday.
#
# How is the quality of ingredients at Il Fiore Restaurant?
# Based on the reviews, the quality of ingredients at Il Fiore Restaurant is highly praised. One reviewer mentioned that the food is always fresh and delicious, while another reviewer specifically highlighted the excellent quality of the ingredients in their pasta dish.
#
# Do they have low-carb dishes at Il Fiore Restaurant?
# Based on the reviews, Il Fiore Restaurant offers a variety of dishes that cater to different dietary preferences. One reviewer mentioned that the owner is willing to make any accommodations, which could include providing low-carb options. Additionally, another reviewer mentioned that their wife had a chicken dish with string beans and mashed potatoes, indicating that
#
# Does Il Fiore Restaurant offer valet parking?
# The restaurant does not offer valet parking.
#
# Is Il Fiore Restaurant good for breakfast?
# The restaurant is not particularly good for breakfast.
#
# Does Il Fiore Restaurant serve Latin American food?
# Il Fiore Restaurant does not offer latin american.
#
# What is the price range at Il Fiore Restaurant?
# The price range at the restaurant is moderate.
#
# How is the flavor of the food at Il Fiore Restaurant?
# Based on the reviews, the flavor of the food at Il Fiore Restaurant is generally well-received. One reviewer mentioned that the asparagus soup was very good, while another reviewer found the pasta to be delicious. However, there were some mixed opinions, with one reviewer mentioning that the pasta could have used a bit more
#
# Is it cozy at Il Fiore Restaurant?
# Yes, according to the reviews, Il Fiore Restaurant has a cozy atmosphere. One reviewer mentioned that the atmosphere was cozy and intimate, while another reviewer described it as cozy and inviting.
#
# Does Il Fiore Restaurant feature the Salmone Al Forno during special events?
# The Salmone Al Forno is occasionally highlighted during holiday menus.
#
# Does Il Fiore Restaurant serve soup?
# Il Fiore Restaurant does not offer soup.
#
# Does Il Fiore Restaurant serve halal food?
# Il Fiore Restaurant may not accommodate halal dietary requirements.
#
# Is Il Fiore Restaurant good for lunch?
# The restaurant is good for lunch.
#
# Does Il Fiore Restaurant offer brunch?
# Il Fiore Restaurant does offer brunch.
#
# How are the salad options at Il Fiore Restaurant?
# Based on the reviews, the salad options at Il Fiore Restaurant are well-liked. One reviewer mentioned enjoying the caprese salad with fresh mozzarella, tomatoes, and basil, while another reviewer praised the antipasto salad with fresh mozzarella, prosciutto, salami, and olives. Both reviewers found
#
# How is the value for money at Il Fiore Restaurant?
# Based on the reviews, the value for money at Il Fiore Restaurant seems to be good. One reviewer mentioned that the prices are reasonable, especially considering the quality of the food. Another reviewer noted that the BYOB policy can help save money for those who bring their own wine.
#
# Is there entertainment at Il Fiore Restaurant?
# Yes, there is entertainment at Il Fiore Restaurant. One reviewer mentioned that the owner, Sal, is very entertaining and makes everyone feel special. Another reviewer mentioned that the waiters are very attentive and professional.
#
# How busy is Il Fiore Restaurant at dinner?
# Based on the reviews, Il Fiore Restaurant can be quite busy during dinner service. One reviewer mentioned that the restaurant was "very busy" on a Friday night, while another reviewer noted that they were "lucky to get a table" on a busy Saturday night.
#
# Do they have good deals at Il Fiore Restaurant?
# Based on the reviews, Il Fiore Restaurant is considered to have good prices for their delicious Italian food. One reviewer mentioned that the food is "delicious and the prices are good too."
#
# Would you describe the ambience at Il Fiore Restaurant as divey?
# The ambience at the restaurant is not divey.
#
# How's the wait time on holidays at Il Fiore Restaurant?
# Based on the reviews, the wait time at Il Fiore Restaurant can be quite long even on non-holiday nights. One reviewer mentioned waiting 40 minutes to be seated and then another 20 minutes without any service. This indicates that the wait time may be longer during peak hours or holidays.
#
# Do they have quick service at Il Fiore Restaurant?
# Yes, according to the reviews, Il Fiore Restaurant has quick service. One reviewer mentioned that the service was quick, while another reviewer specifically praised the quick service they received.
#
# Is there a price-fix menu at Il Fiore Restaurant?
# Based on the reviews, there is no mention of a price-fix menu at Il Fiore Restaurant. However, one reviewer did mention that the prices for wine were not listed on the menu, indicating a lack of transparency in pricing.
#
# Is Il Fiore Restaurant in a safe area?
# Based on the reviews, Il Fiore Restaurant is in a safe area. One reviewer mentioned feeling safe and another mentioned being able to see the kitchen, indicating transparency and accountability in the restaurant's operations.
#
# Is Il Fiore Restaurant a sports bar?
# Il Fiore Restaurant does not provide sports bars service.
#
# Is Il Fiore Restaurant closed on Thursdays?
# Il Fiore Restaurant is not closed on Thursday.
#
# Does Il Fiore Restaurant cater events?
# The restaurant caters events.
#
# Is there a parking lot at Il Fiore Restaurant?
# Yes, there is a parking lot at Il Fiore Restaurant. One reviewer mentioned that parking can be difficult due to the small lot, but another reviewer stated that there is plenty of parking available.
#
# How is the Fettuccine Bolognese at Il Fiore Restaurant?
# The Fettuccine Bolognese is described as: Fettuccine pasta in a classic bolognese sauce..
#
# Is there live music at Il Fiore Restaurant?
# Yes, according to the reviews, Il Fiore Restaurant has live accordion music. One reviewer mentioned that the live music added to the ambiance and fun of the restaurant.
#
# Does Il Fiore Restaurant offer catering?
# Il Fiore Restaurant does not provide caterers service.
#
# Is there kosher food at Il Fiore Restaurant?
# Based on the reviews provided, there is no mention of kosher food at Il Fiore Restaurant. The focus of the reviews is on the delicious and authentic Italian food, specifically the pasta dishes, veal dishes, and desserts.
#
# Does Il Fiore Restaurant serve Japanese food?
# Il Fiore Restaurant does not offer japanese.
#
# Is it crowded at Il Fiore Restaurant?
# Yes, according to the reviews, Il Fiore Restaurant is always crowded. One reviewer mentioned that they were told it is always crowded on weekends, while another reviewer stated that they have been going for 10 years and it is always crowded.
#
# Does Il Fiore Restaurant feature the Insalata Caesar Salad during special events?
# The Insalata Caesar Salad is occasionally highlighted during holiday menus.
#
# How is the music at Il Fiore Restaurant?
# Based on the reviews, the music at Il Fiore Restaurant is described as "just right" and helps create a great atmosphere. One reviewer mentioned that the music was "just right" and another reviewer stated that the restaurant had a "nice atmosphere" with music that contributed to it.
#
# Is Il Fiore Restaurant wheelchair accessible?
# The restaurant is wheelchair accessible.
#
# How is the service at Il Fiore Restaurant?
# Based on the reviews, the service at Il Fiore Restaurant is described as very good and excellent. Reviewers mentioned that the service was prompt, efficient, and attentive. One reviewer specifically mentioned that the service was excellent and highly recommended the restaurant for a great meal and excellent service.
#
# Does Il Fiore Restaurant have WiFi available?
# The restaurant offers free WiFi.
#
# Does Il Fiore Restaurant offer travel services?
# Il Fiore Restaurant does not offer hotels & travel.
#
# Would you describe the ambience at Il Fiore Restaurant as casual?
# The ambience at the restaurant is casual.
#
# Are there seasonal events at Il Fiore Restaurant?
# Yes, based on the reviews, Il Fiore Restaurant hosts events in their wine cellar. One reviewer mentioned having their daughter's Bridal Shower there and praised the staff for being attentive and helpful throughout the event. Another reviewer mentioned having a rehearsal dinner at the restaurant and appreciated the accommodating staff.
#
# Does Il Fiore Restaurant serve Indian food?
# Il Fiore Restaurant does not offer indian.
#
# How are the appetizers at Il Fiore Restaurant?
# Based on the reviews, the appetizers at Il Fiore Restaurant are highly praised. Reviewers mentioned enjoying the antipasto, prosciutto, and mozzarella dishes, as well as the fried calamari and mussels served with the meal. These appetizers were described as delicious and well-prepared.
#
# Does Il Fiore Restaurant serve beer?
# Il Fiore Restaurant does not provide beer service.
#
# Is Il Fiore Restaurant open on Saturdays?
# Il Fiore Restaurant is open on Saturday.
#
# Does Il Fiore Restaurant accept reservations?
# The restaurant accepts reservations.
#
# How attentive are the staff at Il Fiore Restaurant?
# Based on the reviews, the staff at Il Fiore Restaurant are described as attentive and friendly. One reviewer mentioned that the staff is attentive, while another reviewer specifically praised the staff for being attentive.
#
# Is Il Fiore Restaurant in a hotel?
# Il Fiore Restaurant does not offer hotels.
#
# How are the seasonal specials at Il Fiore Restaurant?
# Based on the reviews, the seasonal specials at Il Fiore Restaurant are highly praised. One reviewer mentioned that they enjoyed the butternut squash soup and crab salad during the restaurant week, while another reviewer recommended trying the mussels in white wine sauce. Both reviewers found the specials to be delicious and worth trying.
#
# Is Il Fiore Restaurant open on Mondays?
# Il Fiore Restaurant is not open on Monday.
#
# What makes Carlucci's Waterfront's Tuscan Tower special?
# It's a layered pasta dish featuring their signature chocolate-hazelnut spread, mascarpone cream, candied walnuts, and whipped cream.
#
# How do they handle complaints at Carlucci's Waterfront?
# Based on the reviews, it seems that Carlucci's Waterfront does not handle complaints well. One reviewer mentioned that when they had an issue with their bill, the waitress was unhelpful and dismissive. Another reviewer mentioned that when they had a problem with the service, they were met with excuses and defens
#
# Are there keto options at Carlucci's Waterfront?
# Based on the reviews, Carlucci's Waterfront offers gluten-free options, but there is no specific mention of keto options.
#
# How is Carlucci's Waterfront's Seafood Carnevale prepared?
# Jumbo shrimp stuffed with crab meat, wrapped in bacon, broiled, served in a lite demiglace.
#
# Does Carlucci's Waterfront have vegan options?
# Carlucci's Waterfront may not accommodate vegan dietary requirements.
#
# Is there bike parking at Carlucci's Waterfront?
# Based on the reviews, there is no mention of bike parking at Carlucci's Waterfront. The reviews mainly focus on valet parking and the difficulty of finding regular parking.
#
# Are servers helpful at Carlucci's Waterfront?
# Based on the reviews, servers at Carlucci's Waterfront are generally helpful. One reviewer mentioned that their server was very helpful in explaining the menu and making recommendations. However, another reviewer mentioned that their server was not very helpful in providing information about the food.
#
# Do they confirm reservations at Carlucci's Waterfront?
# Yes, based on the reviews, Carlucci's Waterfront does confirm reservations. One reviewer mentioned that they made reservations about a week in advance and were able to get a table right on the waterfront. Another reviewer mentioned that they had reservations and were seated right on time.
#
# Does Carlucci's Waterfront serve Egyptian food?
# Carlucci's Waterfront does not offer egyptian.
#
# Does Carlucci's Waterfront have vegetarian options?
# Carlucci's Waterfront may not accommodate vegetarian dietary requirements.
#
# Does Carlucci's Waterfront serve Japanese food?
# Carlucci's Waterfront does not offer japanese.
#
# Does Carlucci's Waterfront serve dinner?
# Carlucci's Waterfront does serve dinner.
#
# Does Carlucci's Waterfront offer happy hour specials?
# The restaurant offers happy hour specials.
#
# Do they take walk-ins at Carlucci's Waterfront?
# Based on the reviews, Carlucci's Waterfront does take walk-ins, but it is recommended to make a reservation to avoid a wait. One reviewer mentioned that they walked in without a reservation and had to wait 40 minutes for a table.
#
# Does Carlucci's Waterfront have a tiki bar?
# Carlucci's Waterfront does not provide tiki bars service.
#
# Does Carlucci's Waterfront serve Szechuan food?
# Carlucci's Waterfront does not offer szechuan.
#
# Does Carlucci's Waterfront have vegetarian options?
# Carlucci's Waterfront may not accommodate vegetarian dietary requirements.
#
# How is the value for money at Carlucci's Waterfront?
# ...
# The restaurant is not particularly good for late night dining.
#
# Is it family-friendly at The Kitchen Consigliere?
# Yes, based on the reviews, The Kitchen Consigliere is family-friendly. One reviewer mentioned that the restaurant is family-friendly and casual, while another reviewer specifically mentioned that the restaurant is family-friendly and has a nice ambience.
#
# How are the appetizers at The Kitchen Consigliere?
# Based on the reviews, the appetizers at The Kitchen Consigliere are highly praised. One reviewer mentioned the Calamari Italiano as being perfectly done, while another enjoyed the Grilled Octopus and Shrimp cocktail. Additionally, there was a trio of fried calamari served with a side of spicy aioli that
#
# Does The Kitchen Consigliere serve baked goods?
# The Kitchen Consigliere does not offer bakeries.
#
# Does The Kitchen Consigliere serve salads?
# The Kitchen Consigliere does not offer salad.
#
# Are there keto options at The Kitchen Consigliere?
# Based on the reviews, The Kitchen Consigliere offers a variety of dishes that can be suitable for a keto diet. One reviewer mentioned enjoying the mushroom appetizer, which could be a good keto option. Additionally, the reviewer noted that the menu is full of wonderful options, including seafood, meat, and pasta dishes,
#
# How is the quality of ingredients at The Kitchen Consigliere?
# Based on the reviews, the quality of ingredients at The Kitchen Consigliere is highly praised. One reviewer mentioned that the eggplant parm was made with fresh ingredients and not the usual breaded and fried style. Another reviewer highlighted the homemade desserts as being made with fresh ingredients and not overly sugary.
#
# Does The Kitchen Consigliere serve breakfast or brunch?
# The Kitchen Consigliere does not provide breakfast & brunch service.
#
# Does The Kitchen Consigliere have a wine bar?
# The Kitchen Consigliere does not provide wine bars service.
#
# Can you call for reservations at The Kitchen Consigliere?
# Based on the reviews, it seems that calling ahead for reservations at The Kitchen Consigliere may not guarantee a table for all occasions. One reviewer mentioned calling ahead for Mother's Day but still had to wait 45 minutes beyond their reservation time. Another reviewer mentioned making reservations for Valentine's Day but still had to wait before
#
# Does The Kitchen Consigliere serve Indian food?
# The Kitchen Consigliere does not offer indian.
#
# Is The Kitchen Consigliere closed on Sundays?
# The Kitchen Consigliere is not closed on Sunday.
#
# Does The Kitchen Consigliere serve Mexican food?
# The Kitchen Consigliere does not offer mexican.
#
# Do they have quick service at The Kitchen Consigliere?
# Yes, according to the reviews, The Kitchen Consigliere has quick service. One reviewer mentioned that the service was quick, while another reviewer specifically praised the quick service at the restaurant.
#
# Do they have good deals at The Kitchen Consigliere?
# Yes, according to the reviews, The Kitchen Consigliere offers great deals. One reviewer mentioned the "deal of the day" menu that had really good deals. Another reviewer mentioned that the restaurant is "very reasonably priced" and that they were able to get a table right away on a Saturday night, indicating that it
#
# Would you describe the ambience at The Kitchen Consigliere as divey?
# The ambience at the restaurant is not divey.
#
# Is The Kitchen Consigliere open on Tuesdays?
# The Kitchen Consigliere is open on Tuesday.
#
# What vegetable side dishes does The Kitchen Consigliere offer?
# They offer broccoli rabe, spinach, and roasted potatoes.
#
# How are the prices at The Kitchen Consigliere?
# The prices at The Kitchen Consigliere are mentioned in both reviews. One reviewer mentioned that the prices were reasonable, especially considering the portion sizes. However, another reviewer felt that the prices were a little high, especially for a BYOB restaurant.
#
# Is there a parking lot at The Kitchen Consigliere?
# Based on the reviews, there is no specific mention of a parking lot at The Kitchen Consigliere. However, one reviewer did mention that parking can be a bit congested on busy nights.
#
# How is the customer service at The Kitchen Consigliere?
# Based on the reviews, the customer service at The Kitchen Consigliere is described as attentive, friendly, and exceptional. Reviewers mentioned that the staff was welcoming and made them feel like family. One reviewer specifically mentioned that the service was quick and attentive, even on a busy Friday night.
#
# Do they have low-carb dishes at The Kitchen Consigliere?
# Based on the reviews, The Kitchen Consigliere offers a variety of dishes, including seafood and meat options, which may be suitable for a low-carb diet. However, there is no specific mention of low-carb dishes in the reviews provided.
#
# Does The Kitchen Consigliere serve bubble tea?
# The Kitchen Consigliere does not provide bubble tea service.
#
# Is The Kitchen Consigliere wheelchair accessible?
# Based on the reviews provided, there is no specific mention of wheelchair accessibility at The Kitchen Consigliere.
#
# How is The Kitchen Consigliere's Chicken Sorrento prepared?
# Boneless chicken breast is topped with prosciutto, mozzarella, and fresh grape tomatoes in a light wine sauce.
#
# Does The Kitchen Consigliere serve steaks?
# The Kitchen Consigliere does not offer steakhouses.
#
# Does The Kitchen Consigliere have a tiki bar?
# The Kitchen Consigliere does not provide tiki bars service.
#
# Does The Kitchen Consigliere do event planning?
# The Kitchen Consigliere does not offer party & event planning.
#
# What options does The Kitchen Consigliere offer for shellfish allergies?
# Many dishes can be modified to exclude shellfish, and they clearly mark dishes containing shellfish.
#
# Does The Kitchen Consigliere serve Japanese food?
# The Kitchen Consigliere does not offer japanese.
#
# Would you describe the ambience at The Kitchen Consigliere as upscale?
# The ambience at the restaurant is not upscale.
#
# Is there entertainment at The Kitchen Consigliere?
# Yes, there is entertainment at The Kitchen Consigliere. One reviewer mentioned the entertainment was great, and another reviewer specifically mentioned the entertainment being fantastic.
#
# Would you describe the ambience at The Kitchen Consigliere as intimate?
# The ambience at the restaurant is not intimate.
#
# Is there bike parking at The Kitchen Consigliere?
# Based on the reviews, there is no mention of bike parking at The Kitchen Consigliere. The reviews mainly focus on the valet parking and street parking options available.
#
# What are the brunch hours at The Kitchen Consigliere?
# Brunch hours at The Kitchen Consigliere: Saturday: 17:00-22:00; Sunday: 15:00-21:00
#
# How's the wait time on holidays at The Kitchen Consigliere?
# Based on the reviews, the wait time at The Kitchen Consigliere can be quite long, even on regular nights. One reviewer mentioned waiting 20 minutes to be seated and then another 20 minutes without any service. Another reviewer mentioned waiting 45 minutes to be seated on a busy night.
#
# What preparation styles does The Kitchen Consigliere offer for clams?
# They offer clams in white wine sauce over linguine and in their pasta e fagiolo.
#
# Is it crowded at The Kitchen Consigliere?
# Based on the reviews, The Kitchen Consigliere can get crowded at times. One reviewer mentioned that it was packed for their 7pm reservation on a Saturday night, but they were still seated within 15 minutes. Another reviewer noted that it was crowded for a Friday night, but they were also seated quickly.
#
# Do they confirm reservations at The Kitchen Consigliere?
# Based on the reviews, The Kitchen Consigliere does not confirm reservations. One reviewer mentioned that they had reservations but had to wait 40 minutes to be seated, while another reviewer mentioned that they were told to wait 20 minutes but ended up waiting 40 minutes.
#
# Does The Kitchen Consigliere serve lunch?
# The Kitchen Consigliere does serve lunch.
#
# Do they have a waiting list at The Kitchen Consigliere?
# Based on the reviews, The Kitchen Consigliere does not take reservations for parties of less than 5 people. One reviewer mentioned that they were told they would have to wait for a table, but they were able to find a seat at the bar and order drinks before being seated by a hostess. Another reviewer mentioned
#
# Does The Kitchen Consigliere have TVs?
# The restaurant has TVs.
#
# What's good for sharing at Sushi Kingdom?
# Based on the reviews, the all-you-can-eat sushi at Sushi Kingdom is good for sharing. One reviewer mentioned that they ordered a variety of sushi and shared it with their friends, enjoying the different types of fish and rolls. Another reviewer noted that the sushi was fresh and tasted good, indicating that sharing a selection
#
# Is Sushi Kingdom a cafe?
# Sushi Kingdom does not provide cafes service.
#
# How are dietary modifications handled?
# Clear labeling
#
# How are the main dishes at Sushi Kingdom?
# Based on the reviews, the main dishes at Sushi Kingdom, specifically the sushi and sashimi, are highly praised. Reviewers mentioned that the sushi is fresh and made to order, with a variety of options available. One reviewer even mentioned that the sashimi is so fresh that it "just melts in your
#
# Does Sushi Kingdom have private rooms?
# Based on the reviews provided, there is no mention of Sushi Kingdom having private rooms. The focus of the reviews was on the quality of the food and the service provided.
#
# Is there a parking lot at Sushi Kingdom?
# Yes, there is a parking lot at Sushi Kingdom. One reviewer mentioned that the restaurant is located in a strip mall with plenty of parking options.
#
# What's the price range for classic rolls?
# $8.95-$10.95
#
# How's the wait time on holidays at Sushi Kingdom?
# Based on the reviews, the wait time at Sushi Kingdom can be quite long, even for takeout orders. One reviewer mentioned waiting 20 minutes for their food to be ready, while another reviewer had to wait 15 minutes for their food to come out after ordering at the sushi bar.
#
# Does Sushi Kingdom serve sandwiches?
# Sushi Kingdom does not offer sandwiches.
#
# Is there entertainment at Sushi Kingdom?
# Yes, there is entertainment at Sushi Kingdom. One reviewer mentioned that the staff is entertaining and tries to make the dining experience enjoyable.
#
# How is the hospitality at Sushi Kingdom?
# Based on the reviews, the hospitality at Sushi Kingdom seems to be lacking. One reviewer mentioned that the service was horrible and they had to wait a long time for their food. Another reviewer noted that the servers were rude and dismissive. This indicates that the hospitality at Sushi Kingdom may not be up to par.
#
# Is there live music at Sushi Kingdom?
# Based on the reviews, there is no mention of live music at Sushi Kingdom. The focus seems to be on the all-you-can-eat sushi option and the quality of the food.
#
# When is Sushi Kingdom open on Fridays?
# Sushi Kingdom is open on Friday from 11:00-22:30
#
# Do they have combo deals at Sushi Kingdom?
# Yes, according to the reviews, Sushi Kingdom offers a lunch special that includes miso soup and 3 sushi rolls for $9.99. Additionally, they have a nice selection of appetizers and desserts that can be ordered as part of your meal.
#
# Is Sushi Kingdom closed on Wednesdays?
# Sushi Kingdom is not closed on Wednesday.
#
# Does Sushi Kingdom offer validated parking?
# The restaurant does not offer validated parking.
#
# Are there lunch specials?
# Yes
#
# Are drinks expensive at Sushi Kingdom?
# Based on the reviews, drinks at Sushi Kingdom are not expensive. One reviewer mentioned that the food is not expensive, and another reviewer mentioned that the restaurant is BYOB, which can help save money on drinks.
#
# What indicates their noodle quality?
# Fresh preparation
#
# What are the best dishes at Sushi Kingdom?
# Based on the reviews, the best dishes at Sushi Kingdom are the all-you-can-eat sushi, sashimi, and appetizers. Reviewers mentioned that the sushi and sashimi were fresh and of high quality, and that the appetizers were also delicious. One reviewer specifically mentioned that the squid appetizer
#
# Does Sushi Kingdom serve coffee and tea?
# Sushi Kingdom does not provide coffee & tea service.
#
# What seafood varieties are offered?
# Multiple options
#
# How fresh are their sushi ingredients?
# High-quality fish selections
#
# Does Sushi Kingdom serve steaks?
# Sushi Kingdom does not offer steakhouses.
#
# What are their signature salads?
# Creative options
#
# Does Sushi Kingdom do event planning?
# Sushi Kingdom does not offer party & event planning.
#
# Is Sushi Kingdom good for breakfast?
# The restaurant is not particularly good for breakfast.
#
# Is it family-friendly at Sushi Kingdom?
# Yes, according to the reviews, Sushi Kingdom is family-friendly. One reviewer mentioned that the staff was very friendly, and another reviewer noted that the restaurant was packed with families during their visit.
#
# Does Sushi Kingdom serve sushi?
# Sushi Kingdom offers sushi bars.
#
# What's trending at Sushi Kingdom?
# Based on the reviews, Sushi Kingdom is known for its all-you-can-eat sushi option, which is popular among customers. Additionally, the restaurant offers a wide variety of appetizers, salads, and desserts, making it a good spot for a family dinner.
#
# Does Sushi Kingdom serve Traditional American food?
# Sushi Kingdom does not offer american (traditional).
#
# Do they have low-carb dishes at Sushi Kingdom?
# Based on the reviews, Sushi Kingdom offers a variety of options including sushi, sashimi, rolls, and teriyaki dishes. While the reviews do not specifically mention low-carb dishes, the menu appears to have a variety of choices that may cater to different dietary preferences.
#
# How is the overall food quality at Sushi Kingdom?
# Based on the reviews, the overall food quality at Sushi Kingdom is highly praised. Reviewers mentioned that the food is of high quality, fresh, and delicious. One reviewer specifically mentioned that the food is "fresh and delicious" and another reviewer stated that they have been going to Sushi Kingdom for 5 years and
#
# When is Sushi Kingdom open on Sundays?
# Sushi Kingdom is open on Sunday from 11:00-22:00
#
# Does Sushi Kingdom have a bar?
# Sushi Kingdom does not provide bars service.
#
# Do they take walk-ins at Sushi Kingdom?
# Based on the reviews, Sushi Kingdom does take walk-ins, but it is recommended to make reservations, especially on weekends. One reviewer mentioned that they had to wait 20 minutes for a table on a Saturday night, while another reviewer advised making reservations to avoid a wait.
#
# How are the appetizers at Sushi Kingdom?
# Based on the reviews, the appetizers at Sushi Kingdom are highly praised. One reviewer mentioned that the appetizers come out quickly and are fresh, while another reviewer specifically recommended trying the squid and hokkigai appetizers, stating that they are delicious and can be dipped in a ponzu sauce for added flavor
#
# How attentive are the staff at Sushi Kingdom?
# Based on the reviews, the staff at Sushi Kingdom are described as attentive and helpful. One reviewer mentioned that the staff was attentive and helpful, while another reviewer specifically praised the waitress for being attentive.
#
# Does Sushi Kingdom serve Italian food?
# Sushi Kingdom does not offer italian.
#
# How busy is Sushi Kingdom at dinner?
# Based on the reviews, Sushi Kingdom can be busy during dinner time. One reviewer mentioned that the restaurant was busy on a Saturday night, while another reviewer noted that the restaurant was busy on a Friday night as well.
#
# Are the portion sizes worth the price at Sushi Kingdom?
# Based on the reviews, the portion sizes at Sushi Kingdom are worth the price. One reviewer mentioned that the portion sizes are huge and you get a lot of food for the price. Another reviewer specifically mentioned that the all-you-can-eat sushi option is worth the price if you can eat a lot.
#
# Would you describe the ambience at Sushi Kingdom as intimate?
# The ambience at the restaurant is not intimate.
